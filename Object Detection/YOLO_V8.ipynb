# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# detection

# !yolo task = detect mode = predict model =yolov8n.pt conf = 0.25 source= "https://www.westend61.de/images/0000845608pw/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg"
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 184MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 168k/168k [00:00<00:00, 630kB/s]
# image 1/1 /content/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg: 448x640 7 persons, 3 cars, 1 handbag, 1 suitcase, 1 potted plant, 261.4ms
# Speed: 20.4ms preprocess, 261.4ms inference, 21.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image

# %%
Image(filename= '/content/runs/detect/predict/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg')

# %%
# segmentation

# !yolo task = segment mode = predict model =yolov8n-seg.pt conf = 0.25 source= "https://www.westend61.de/images/0000845608pw/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg"
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 231MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# Found https://www.westend61.de/images/0000845608pw/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg locally at rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg
# image 1/1 /content/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg: 448x640 8 persons, 8 cars, 1 umbrella, 2 handbags, 1 suitcase, 298.8ms
# Speed: 8.5ms preprocess, 298.8ms inference, 71.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Classification

# !yolo task = classify mode = predict model =yolov8n-cls.pt conf = 0.25 source= "https://www.westend61.de/images/0000845608pw/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg"
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 209MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# Found https://www.westend61.de/images/0000845608pw/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg locally at rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg
# ...
# 100% 755k/755k [00:00<00:00, 98.7MB/s]
# image 1/1 /content/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg: 224x224 miniskirt 0.14, bearskin 0.07, sarong 0.05, shield 0.04, accordion 0.04, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename= '/content/runs/classify/predict/rear-view-of-women-with-shopping-bags-walking-on-city-street-CAVF01762.jpg')

# %% [markdown]
# # For Training on Custom Dataset

# %%
# !yolo task=detect mode=train model=yolov8l.pt data =/content/plastics-3/data.yaml epochs=51 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 234MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...
